# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('csv_files/iris.csv')
df.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
species = df['PetalLengthCm']

# %%
species.value_counts()
# Out:
# 1.5    14
# 1.4    12
# 5.1     8
# 4.5     8
# 1.6     7
# 1.3     7
# 5.6     6
# 4.7     5
# 4.9     5
# 4.0     5
# 4.2     4
# 5.0     4
# 4.4     4
# 4.8     4
# 1.7     4
# 3.9     3
# 4.6     3
# 5.7     3
# 4.1     3
# 5.5     3
# 6.1     3
# 5.8     3
# 3.3     2
# 5.4     2
# 6.7     2
# 5.3     2
# 5.9     2
# 6.0     2
# 1.2     2
# 4.3     2
# 1.9     2
# 3.5     2
# 5.2     2
# 3.0     1
# 1.1     1
# 3.7     1
# 3.8     1
# 6.6     1
# 6.3     1
# 1.0     1
# 6.9     1
# 3.6     1
# 6.4     1
# Name: PetalLengthCm, dtype: int64

# %%
plt.hist(species)
# Out:
# (array([37., 13.,  0.,  3.,  8., 26., 29., 18., 11.,  5.]),
#  array([1.  , 1.59, 2.18, 2.77, 3.36, 3.95, 4.54, 5.13, 5.72, 6.31, 6.9 ]),
#  <BarContainer object of 10 artists>)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
# visualize with two variant Numerical and Categorical values
x1 = df['Species']
y1 = df['SepalLengthCm']

plt.bar(x1,y1)
# Out:
# <BarContainer object of 150 artists>

# %%
df['Species'].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot: >

# %%
# visualize with two variant Numerical and Numerical values
x2 = df['SepalLengthCm']
y2 = df['SepalWidthCm']
plt.scatter(x2,y2,color="green")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
plt.show()

# %%
import seaborn as sns

# %%
sns.histplot(species,kde=True)
# Out:
# <AxesSubplot: xlabel='PetalLengthCm', ylabel='Count'>

# %%
Iris_setosa = df[df["Species"] == "Iris-setosa"]
Iris_setosa.head()
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.FacetGrid(Iris_setosa,hue="Species",height=6).map(sns.histplot,'PetalLengthCm',kde=True).add_legend()

# %%
sns.FacetGrid(df,hue="Species",height=5).map(sns.histplot,'PetalLengthCm',kde=True).add_legend()

# %%
sns.FacetGrid(df,hue="Species",height=6).map(sns.kdeplot,'PetalWidthCm').add_legend()

# %%
df['Species']
# Out:
# 0         Iris-setosa
# 1         Iris-setosa
# 2         Iris-setosa
# 3         Iris-setosa
# 4         Iris-setosa
#             ...
# 145    Iris-virginica
# 146    Iris-virginica
# 147    Iris-virginica
# 148    Iris-virginica
# 149    Iris-virginica
# Name: Species, Length: 150, dtype: object

# %%
sns.countplot(x='Species',data=df)
# Out:
# <AxesSubplot: xlabel='Species', ylabel='count'>

# %%
df['Species'].value_counts().plot(kind='pie',autopct="%.2f%%")
# Out:
# <AxesSubplot: ylabel='Species'>

# %% [markdown]
# ## Bivarient Exploratory Data Analysis
