# %%
import numpy as np

# %%
# Creating new array with numpy library
arr = np.array([(1,23,4),(20,30,49),(20,90,390),(10,39,34),(30,29)],dtype="object")

# %%
print(arr)
# Out:
# [(1, 23, 4) (20, 30, 49) (20, 90, 390) (10, 39, 34) (30, 29)]

# %%
arr.ndim
# Out:
# 1

# %%
np.where(arr[0][1] == 23)
# Out:
# (array([0], dtype=int64),)

# %%
import pandas as pd

# %%
jsondata = pd.read_csv('adidas.csv')
dataset = pd.DataFrame(jsondata)
print(dataset.columns)
datas = dataset[dataset['original_price'].notna()]
maindata = datas[['selling_price','average_rating']]
print(maindata.head())
val = datas['selling_price']
# Out:
# Index(['url', 'name', 'sku', 'selling_price', 'original_price', 'currency',
#        'availability', 'color', 'category', 'source', 'source_website',
#        'breadcrumbs', 'description', 'brand', 'images', 'country', 'language',
#        'average_rating', 'reviews_count', 'crawled_at'],
#       dtype='object')
#     selling_price  average_rating
# 15             20             4.8
# 16             20             4.8
# 18             20             4.8
# 19             48             4.2
# 20             64             4.4

# %%
import matplotlib.pyplot as plt

# %%
# maindata.plot.scatter(x="average_rating",y="selling_price")
maindata.plot.scatter(x="selling_price",y='average_rating')
plt.show()
